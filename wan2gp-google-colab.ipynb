# %% [markdown]
# <a href="https://colab.research.google.com/github/TroyMiner/Fastvideo/blob/main/wan2gp-google-colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Wan2GP on Google Colab
#
# Sets up [Wan2GP](https://github.com/deepbeepmeep/Wan2GP) in a fresh GPU-backed Colab session.
#
# Run the cells in order to prepare the runtime, install dependencies, and launch the Gradio interface. Click on the link in the output from the last cell to launch the app in your browser.
#
# > **Colab VRAM note:** the free tier usually assigns a 15 GB T4 GPU. Most Wan2GP models exceed that budget; the Wan 2.2 TextImage2Video FastWan model works, producing roughly a 5 second 480p clip in about 8 minutes.

# %% [markdown]
# ## 1. Confirm the accelerator
#
# Choose `Runtime → Change runtime type` and select **GPU** before running anything else.
#
# If this cell raises an error, go back to `Runtime → Change runtime type`, pick **GPU** and save.

# %%
import subprocess

try:
    subprocess.run(['nvidia-smi'], check=True)
except Exception as exc:
    raise RuntimeError(
        'GPU not detected. In Colab, open Runtime → Change runtime type, select GPU (or TPU if GPUs are unavailable), save, then rerun this cell.'
    ) from exc

# %% [markdown]
# ## 2. Configure the workspace path
#
# Choose where Wan2GP should be installed. Update `WAN2GP_ROOT` if you prefer a different location.

# %%
from pathlib import Path

WAN2GP_ROOT = Path('/content/Wan2GP').resolve()
print(f'Wan2GP will be installed to: {WAN2GP_ROOT}')
# Out:
# Wan2GP will be installed to: /content/Wan2GP

# %% [markdown]
# ## 3. Download or update Wan2GP
#
# Clone the repository if it is not present yet; otherwise pull the latest changes.

# %%
import subprocess

repo_url = 'https://github.com/deepbeepmeep/Wan2GP.git'
if WAN2GP_ROOT.exists():
    print('Repository already exists. Pulling latest changes...')
    subprocess.run(['git', '-C', str(WAN2GP_ROOT), 'pull'], check=True)
else:
    subprocess.run(['git', 'clone', repo_url, str(WAN2GP_ROOT)], check=True)

# %% [markdown]
# ## 4. Install system dependencies
#
# Install shared libraries needed for video and audio processing. If you see a warning about skipping an extra repository, it is safe to ignore.

# %%
import os, subprocess

env = os.environ.copy()
env['DEBIAN_FRONTEND'] = 'noninteractive'

subprocess.run(['sudo', 'apt-get', 'update', '-qq'], check=True, env=env)
subprocess.run([
    'sudo', 'apt-get', 'install', '-y', '--no-install-recommends',
    'ffmpeg', 'libglib2.0-0', 'libgl1', 'libportaudio2'
], check=True, env=env)
# Out:
# CompletedProcess(args=['sudo', 'apt-get', 'install', '-y', '--no-install-recommends', 'ffmpeg', 'libglib2.0-0', 'libgl1', 'libportaudio2'], returncode=0)

# %% [markdown]
# ## 5. Install Python dependencies
#
# Install PyTorch, xformers and Wan2GP's Python packages.

# %%
import os, subprocess, sys

env = os.environ.copy()
env.setdefault('DEBIAN_FRONTEND', 'noninteractive')

subprocess.run([sys.executable, '-m', 'pip', 'install', '--upgrade', 'pip', 'setuptools', 'wheel'], check=True, env=env)
subprocess.run([sys.executable, '-m', 'pip', 'install', 'torch==2.8.0', 'torchvision', 'torchaudio', '--index-url', 'https://download.pytorch.org/whl/cu128'], check=True, env=env)
subprocess.run([sys.executable, "-m", "pip", "install", "xformers==0.0.32.post2", "--index-url", "https://download.pytorch.org/whl/cu128"],
               check=True, env=env)
subprocess.run([sys.executable, '-m', 'pip', 'install', '-r', str(WAN2GP_ROOT / 'requirements.txt')], check=True, env=env)
# Out:
# CompletedProcess(args=['/usr/bin/python3', '-m', 'pip', 'install', '-r', '/content/Wan2GP/requirements.txt'], returncode=0)

# %% [markdown]
# ## 5b. Force a headless matplotlib backend
#
# Ensure Wan2GP's preprocessing tools use the headless Agg backend so Step 6 launches cleanly in Colab.

# %%
from pathlib import Path

# Replace the TkAgg backend with the headless Agg backend if present.
target = WAN2GP_ROOT / 'preprocessing/matanyone/tools/interact_tools.py'
needle = "matplotlib.use('TkAgg')"
replacement = "matplotlib.use('Agg')"

if not target.exists():
    print(f'Skipping: {target} not found.')
else:
    text = target.read_text()
    if replacement in text:
        print('Agg backend already set; no change needed.')
    elif needle in text:
        target.write_text(text.replace(needle, replacement, 1))
        print('Replaced TkAgg with Agg in interact_tools.py.')
    else:
        print('Backend call not found; no change made.')
# Out:
# Replaced TkAgg with Agg in interact_tools.py.

# %% [markdown]
# ## 6. Launch Wan2GP
#
# Run the Gradio interface. You will find the gradio link in the output. Click on the link to access the UI. Keep the cell running to stay connected; stop it with the square **Stop** button when you are finished.

# %%
import os, subprocess, sys, threading, time

env = os.environ.copy()
env.setdefault('WAN_CACHE_DIR', str(WAN2GP_ROOT / 'models'))
cmd = [
    sys.executable,
    '-u',
    'wgp.py',
    '--listen',
    '--server-port', '7860',
    '--share',
    '--profile', '5',
    '--vae-config', '4',
    '--preload', '0'
]
print('Launching Wan2GP…')
process = subprocess.Popen(
    cmd,
    cwd=str(WAN2GP_ROOT),
    env=env,
    stdout=subprocess.PIPE,
    stderr=subprocess.STDOUT,
    text=True,
    bufsize=1,
)
stop_event = threading.Event()

def keepalive():
    while not stop_event.is_set():
        time.sleep(45)
        if stop_event.is_set():
            break
        print('[keepalive] Notebook cell still running…')

keepalive_thread = threading.Thread(target=keepalive, daemon=True)
keepalive_thread.start()

try:
    for line in iter(process.stdout.readline, ''):
        if not line:
            break
        print(line, end='')
except KeyboardInterrupt:
    print('Stopping Wan2GP…')
    process.terminate()
finally:
    stop_event.set()
    process.wait()
    keepalive_thread.join(timeout=1)
    print(f'Wan2GP stopped (return code: {process.returncode}).')
# Out:
# Launching Wan2GP…
# 2026-01-20 15:16:41.681464: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-01-20 15:16:41.700330: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1768922201.722499    4830 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1768922201.729935    4830 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1768922201.748979    4830 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768922201.749004    4830 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768922201.749006    4830 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768922201.749008    4830 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-01-20 15:16:41.753996: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# [Plugins] Auto-installing default plugin: wan2gp-gallery...
# Ignoring comtypes: markers 'sys_platform == "win32"' don't match your environment
# [Plugins] Install result for wan2gp-gallery: [Success] Plugin 'wan2gp-gallery' installed. Please enable it in the list and restart WanGP.
# [Plugins] Auto-installing default plugin: wan2gp-lora-multipliers-ui...
# [Plugins] Install result for wan2gp-lora-multipliers-ui: [Success] Plugin 'wan2gp-lora-multipliers-ui' installed. Please enable it in the list and restart WanGP.
# [Plugins] Disabling newly installed default plugins...
# /usr/local/lib/python3.12/dist-packages/gradio/components/dropdown.py:227: UserWarning: The value passed into gr.Dropdown() is not in the list of choices. Please update the list of choices to include: 4 or set allow_custom_value=True.
#   warnings.warn(
# * Running on local URL:  http://0.0.0.0:7860
# * Running on public URL: https://a586ec427d551e5b42.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# Loading Model 'ckpts/ltx-2-19b-distilled-fp8_diffusion_model.safetensors' ...
# [keepalive] Notebook cell still running…
# Loading Text Encoder 'ckpts/gemma-3-12b-it-qat-q4_0-unquantized/gemma-3-12b-it-qat-q4_0-unquantized_quanto_bf16_int8.safetensors' ...
# ************ Memory Management for the GPU Poor (mmgp 3.7.0) by DeepBeepMeep ************
# Hooked to model 'transformer' (X0Model)
# Async loading plan for model 'transformer' : base size of 443.16 MB will be preloaded with a 736.38 MB async circular shuttle
# Hooked to model 'text_encoder' (Gemma3ForCausalLM)
# Async loading plan for model 'text_encoder' : base size of 1920.48 MB will be preloaded with a 213.87 MB async circular shuttle
# Hooked to model 'text_embedding_projection' (GemmaFeaturesExtractorProjLinear)
# Hooked to model 'text_embeddings_connector' (GemmaTextEmbeddingsConnectorModel)
# Hooked to model 'vae' (VideoDecoder)
# Async loading plan for model 'vae' : base size of 7.07 MB will be preloaded with a 540.02 MB async circular shuttle
# Hooked to model 'video_encoder' (VideoEncoder)
# Async loading plan for model 'video_encoder' : base size of 13.92 MB will be preloaded with a 864.02 MB async circular shuttle
# Hooked to model 'audio_encoder' (AudioEncoder)
# Hooked to model 'audio_decoder' (AudioDecoder)
# Hooked to model 'vocoder' (Vocoder)
# Hooked to model 'spatial_upsampler' (LatentUpsampler)
# [keepalive] Notebook cell still running…
#
#   0%|          | 0/8 [00:00<?, ?steps/s]
# [keepalive] Notebook cell still running…
#  12%|█▎        | 1/8 [00:36<04:17, 36.81s/steps]
#  25%|██▌       | 2/8 [00:49<02:14, 22.38s/steps]
#  38%|███▊      | 3/8 [01:00<01:26, 17.38s/steps]
#  50%|█████     | 4/8 [01:11<00:59, 14.98s/steps]
# [keepalive] Notebook cell still running…
#  62%|██████▎   | 5/8 [01:23<00:41, 13.68s/steps]
#  75%|███████▌  | 6/8 [01:34<00:25, 12.87s/steps]
#  88%|████████▊ | 7/8 [01:45<00:12, 12.37s/steps]
# 100%|██████████| 8/8 [01:57<00:00, 12.03s/steps]
# 100%|██████████| 8/8 [01:57<00:00, 14.64s/steps]
#
# [keepalive] Notebook cell still running…
#   0%|          | 0/3 [00:00<?, ?steps/s]
#  33%|███▎      | 1/3 [00:13<00:27, 13.94s/steps]
#  67%|██████▋   | 2/3 [00:27<00:13, 13.64s/steps]
# 100%|██████████| 3/3 [00:40<00:00, 13.52s/steps]
# 100%|██████████| 3/3 [00:40<00:00, 13.58s/steps]
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# New video saved to Path: outputs/2026-01-20-16h10m20s_seed538689790_A realistic cinematic shot of a man in his early 30s wearing a faded blue jean jacket standing at th.mp4
# Audio notification fallback: /proc/asound/cards is missing (no ALSA devices); using terminal beep.
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
#
#   0%|          | 0/8 [00:00<?, ?steps/s]
# [keepalive] Notebook cell still running…
#  12%|█▎        | 1/8 [00:12<01:25, 12.17s/steps]
#  25%|██▌       | 2/8 [00:23<01:10, 11.80s/steps]
#  38%|███▊      | 3/8 [00:35<00:58, 11.63s/steps]
#  50%|█████     | 4/8 [00:46<00:46, 11.52s/steps]
# [keepalive] Notebook cell still running…
#  62%|██████▎   | 5/8 [00:57<00:34, 11.49s/steps]
#  75%|███████▌  | 6/8 [01:09<00:22, 11.46s/steps]
#  88%|████████▊ | 7/8 [01:20<00:11, 11.44s/steps]
# 100%|██████████| 8/8 [01:32<00:00, 11.41s/steps]
# 100%|██████████| 8/8 [01:32<00:00, 11.51s/steps]
#
# [keepalive] Notebook cell still running…
#   0%|          | 0/3 [00:00<?, ?steps/s]
#  33%|███▎      | 1/3 [00:13<00:27, 13.95s/steps]
#  67%|██████▋   | 2/3 [00:27<00:13, 13.56s/steps]
# 100%|██████████| 3/3 [00:40<00:00, 13.44s/steps]
# 100%|██████████| 3/3 [00:40<00:00, 13.51s/steps]
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# New video saved to Path: outputs/2026-01-20-16h26m05s_seed509355656_A realistic cinematic interior shot inside an isolated farmhouse at night. The same man in his early.mp4
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
#
# [keepalive] Notebook cell still running…
#   0%|          | 0/8 [00:00<?, ?steps/s]
#  12%|█▎        | 1/8 [00:12<01:24, 12.01s/steps]
#  25%|██▌       | 2/8 [00:23<01:09, 11.61s/steps]
#  38%|███▊      | 3/8 [00:34<00:57, 11.48s/steps]
# [keepalive] Notebook cell still running…
#  50%|█████     | 4/8 [00:46<00:45, 11.45s/steps]
#  62%|██████▎   | 5/8 [00:57<00:34, 11.43s/steps]
#  75%|███████▌  | 6/8 [01:08<00:22, 11.42s/steps]
#  88%|████████▊ | 7/8 [01:20<00:11, 11.37s/steps]
# 100%|██████████| 8/8 [01:31<00:00, 11.36s/steps]
# 100%|██████████| 8/8 [01:31<00:00, 11.43s/steps]
# [keepalive] Notebook cell still running…
#
#   0%|          | 0/3 [00:00<?, ?steps/s]
#  33%|███▎      | 1/3 [00:13<00:27, 13.88s/steps]
#  67%|██████▋   | 2/3 [00:27<00:13, 13.54s/steps]
# 100%|██████████| 3/3 [00:40<00:00, 13.42s/steps]
# 100%|██████████| 3/3 [00:40<00:00, 13.49s/steps]
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# New video saved to Path: outputs/2026-01-20-16h34m32s_seed789764528_A realistic cinematic interior shot inside the farmhouse bedroom at night. The same man in his early.mp4
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
#
#   0%|          | 0/8 [00:00<?, ?steps/s]
# [keepalive] Notebook cell still running…
#  12%|█▎        | 1/8 [00:12<01:24, 12.06s/steps]
#  25%|██▌       | 2/8 [00:23<01:09, 11.66s/steps]
#  38%|███▊      | 3/8 [00:34<00:57, 11.60s/steps]
#  50%|█████     | 4/8 [00:46<00:46, 11.51s/steps]
# [keepalive] Notebook cell still running…
#  62%|██████▎   | 5/8 [00:57<00:34, 11.46s/steps]
#  75%|███████▌  | 6/8 [01:09<00:22, 11.42s/steps]
#  88%|████████▊ | 7/8 [01:20<00:11, 11.39s/steps]
# 100%|██████████| 8/8 [01:31<00:00, 11.37s/steps]
# 100%|██████████| 8/8 [01:31<00:00, 11.46s/steps]
#
# [keepalive] Notebook cell still running…
#   0%|          | 0/3 [00:00<?, ?steps/s]
#  33%|███▎      | 1/3 [00:13<00:27, 13.91s/steps]
#  67%|██████▋   | 2/3 [00:27<00:13, 13.52s/steps]
# 100%|██████████| 3/3 [00:40<00:00, 13.39s/steps]
# 100%|██████████| 3/3 [00:40<00:00, 13.46s/steps]
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# New video saved to Path: outputs/2026-01-20-16h41m50s_seed787535763_A realistic cinematic exterior shot at dawn outside the same isolated farmhouse. The same man in his.mp4
#
# [keepalive] Notebook cell still running…
#   0%|          | 0/8 [00:00<?, ?steps/s]
#  12%|█▎        | 1/8 [00:12<01:24, 12.05s/steps]
#  25%|██▌       | 2/8 [00:23<01:09, 11.64s/steps]
#  38%|███▊      | 3/8 [00:34<00:57, 11.49s/steps]
# [keepalive] Notebook cell still running…
#  50%|█████     | 4/8 [00:46<00:45, 11.47s/steps]
#  62%|██████▎   | 5/8 [00:57<00:34, 11.44s/steps]
#  75%|███████▌  | 6/8 [01:08<00:22, 11.43s/steps]
#  88%|████████▊ | 7/8 [01:20<00:11, 11.40s/steps]
# 100%|██████████| 8/8 [01:31<00:00, 11.39s/steps]
# 100%|██████████| 8/8 [01:31<00:00, 11.46s/steps]
#
# [keepalive] Notebook cell still running…
#   0%|          | 0/3 [00:00<?, ?steps/s]
#  33%|███▎      | 1/3 [00:14<00:28, 14.04s/steps]
#  67%|██████▋   | 2/3 [00:27<00:13, 13.64s/steps]
# 100%|██████████| 3/3 [00:40<00:00, 13.48s/steps]
# 100%|██████████| 3/3 [00:40<00:00, 13.56s/steps]
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# New video saved to Path: outputs/2026-01-20-16h47m15s_seed163620726_A realistic cinematic point-of-view shot from inside a moving pickup truck, seen through the front w.mp4
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# [keepalive] Notebook cell still running…
# Stopping Wan2GP…
# Wan2GP stopped (return code: -15).
